# %% [markdown]
# # THE SPARK FOUNDATION
# # Data Science & Business Analytics Intern May 2023

# %% [markdown]
# ## Task: Exploratory Data Analysis on "Superstore Data".
#
# ### Author: Ankit Sharma
#
# ### The aim of this task is to perform exploratory data analysis on the dataset **SUPERSTORE  DATA**, and find out the problem of bussinesses, identifying the key areas for improvemet. Also, need to find out profit and losses in different regions and growth of industries in different sectors.

# %% [markdown]
# # Importing Required Python Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# ### Loading Dataset

# %%
Data = pd.read_csv("SampleSuperstore.csv")

# %%
Data.shape
# Out:
# (9994, 13)

# %%
Data
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
Data.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %% [markdown]
# ### Data Preprocessing

# %%
Data.drop_duplicates(keep= 'first',inplace=True)

# %%
Data
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
Data.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
Data.shape
# Out:
# (9977, 13)

# %% [markdown]
# ### _Conclusion_
# - **Removed identical rows from data**
# - **There is no null values present in the data.**

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# ### 1. Let's find the states having maximum number of sales

# %%
Sales = Data.groupby("State").Sales.sum().nlargest(n =10)

# %%
plt.style.use('seaborn')
Top_10_Sales.plot(kind ='bar', figsize =(14,8), fontsize =14, color='orange')
plt.xlabel("States", fontsize =13)
plt.ylabel("Total Sales",fontsize =13)
plt.title("States by Sales",fontsize =16)
plt.show()

# %% [markdown]
# ### _Conclusion:_
# - **California, New York, Texas, Washington, and Pennsylvania are the leading states in sales.**
# - **California tops the table by having 400000 sales.**

# %% [markdown]
# ### 2. Now, find the states having maximum profits

# %%
Profits = Data.groupby("State").Profit.sum().nlargest(n =10)

# %%
plt.style.use('seaborn')
Top_10_Profits.plot(kind ='bar', figsize =(14,8), fontsize =14, color='Orange')
plt.xlabel("States", fontsize =13)
plt.ylabel("Total Profits",fontsize =13)
plt.title("States by Profits",fontsize =16)
plt.show()

# %% [markdown]
# ### _Conclusion:_
# - **California, New York, Washington, Michigan, and Virginia, sharing most of the profits.**
# - **California and New York states having maximum profits.**

# %% [markdown]
# ### 3. Relational Analysis

# %%
financial=Data.loc[:,['Sales','Quantity','Discount','Profit']]
g = sns.PairGrid(financial)
g.map_upper(sns.scatterplot,color='purple')
g.map_lower(sns.scatterplot, color='brown')
g.map_diag(plt.hist)

# %% [markdown]
# ### _Conclusion:_
# **In above we see that there is some relation between sales and profit and also there is some relation between Discount and Profit.<br>**
# **Plotting heat will give more clearity over this.**

# %% [markdown]
# ### 4. Correlation map

# %%
correlation=financial.corr()
sns.heatmap(correlation,xticklabels=correlation.columns,yticklabels=correlation.columns,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### _Conclusion:_
#
# - **sales and profits are positively correlated.**
# - **Discount and Profits are Negatively correlated.**

# %% [markdown]
# ### 5. Let's find maximum and minimum profit by categories.

# %%
data1=Data[Data['Discount']!=0]

# %%
pivot=pd.pivot_table(data1,index='Sub-Category',values='Profit')
pivot.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Sub-Category'>

# %% [markdown]
# ### _Conclusion:_
# - **Above analysis clearly states that Copiers had maximum profit and machines had maximum loss.**

# %%
pivot=pd.pivot_table(data1,index='Sub-Category',values='Sales')
pivot.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Sub-Category'>

# %% [markdown]
# ### _Conclusion:_
# - **Copiers and Machines has first snd second highest sales respectivey.**

# %% [markdown]
# ### 6. Distrubution of Profits across diffrent regions

# %%
plt.figure(figsize = (12,4))
sns.set(font_scale=1, palette= "viridis")
sns.barplot(data = Data , x = "Region",y = "Profit" ,hue = "Segment", color='orange')
plt.show()

# %% [markdown]
# ### _Conclusion:_
# - **Above plot states that overall each segment is profitable in every region.**

# %% [markdown]
# ### 7. Distrubution of Profits across diffrent categories.

# %%
plt.figure(figsize = (12,4))
sns.set(font_scale=1, palette= "viridis")
sns.barplot(data = Data , x = "Region",y = "Profit" ,hue = "Category", color="orange")
plt.show()

# %% [markdown]
# ### _Conclusion:_
# - **Furniture category is the only loss making sector that to only in Central Region.**

# %% [markdown]
# ### Advanced data analysis for investigation of looses in Furniture Category.

# %% [markdown]
# ### 8. Investigating losses in Furniture category in the Central region

# %%
# Grouping Data by Region and only slicing Data for Central Region from whole Data Set
gb_Central = list(Data.groupby("Region"))[0][1]

# %%
plt.figure(figsize=(12, 4))
sns.set(font_scale=1.5, palette="viridis")
sns.barplot(data=gb_Central, x="Category", y="Profit", hue="Ship Mode", color="green")
plt.title("Investigation of Central Region: Profit Making (by Ship Mode)")
plt.xlabel("Category")
plt.ylabel("Profit")
plt.xticks(rotation=45)
plt.legend(title="Ship Mode")
plt.show()

# %% [markdown]
# ### _Conclusion:_
# - **Losses are inccured in Furniture Cateory irrespective to ship mode in Central Region**

# %%
# Slicing Furniture Data from whole data set
gb_Category_Furniture =list(list(Data.groupby("Region"))[0][1].groupby("Category"))[0][1]

# %%
plt.figure(figsize = (12,8))
sns.set(font_scale=1.4)
sns.heatmap(gb_Category_Furniture.corr() , annot = True, cmap ="Reds")
plt.show()

# %% [markdown]
# ### _Conclusion:_
# - **There is unusually high positive correlation between Postal Code and Discount.**
# - **Also, Their is negative correlation between Discount and Sales eventhough dicounts are entered as positive values... i.e. they are not helping in improving sales of "Furniture" category of the company.**

# %% [markdown]
# ### 9. Lets investigate individual performance by states in the central region.

# %%
plt.figure(figsize = (12,8))
sns.set(font_scale=1, palette= "viridis")
sns.barplot(data = gb_Category_Furniture , x = "State",y = "Profit" ,hue = "Sub-Category", color="red")
plt.title("Investigation of Central Region Furniture Category: Profit Analysis(by Sub Category)", fontsize = 20)
plt.show()

# %%
plt.figure(figsize = (12,8))
sns.set(font_scale=1, palette= "viridis")
sns.barplot(data = gb_Category_Furniture , x = "State",y = "Profit" ,hue = "Segment", color="orange")
plt.title("Investigation of Central Region Furniture Category: Profit Analysis(by Segment)", fontsize = 20)
plt.show()

# %% [markdown]
# ### _Conclusion:_
# - **Texas and Illiois are only two states contributing to all the losses in Furniture category in the Central Region
# Losses in Tables Sub Category is significanlty high.**

# %% [markdown]
# ### 10. lets find what they are doing differently from other?

# %%
plt.figure(figsize = (12,8))
sns.set(font_scale=1, palette= "viridis")
sns.barplot(data = gb_Category_Furniture , x = "State",y = "Discount" ,hue = "Sub-Category", color="green")
plt.title("Discounts provided by each state", fontsize = 20)
plt.show()

# %% [markdown]
# ### _Conclusion:_
#
# - **Texas and Illinois are only states providing discounts in the whole central region this justifies high positive correlation between postal codes and discounts.**
#
# **Also, these discounts are very high!**
# - **60% on Furnishings.**
# - **30% on Bookcases and Chairs.**
# - **50% disount on Tables in Illinois and 30% in Texas.**

# %% [markdown]
# ### 11. Now, finding the sector vise Profit variations

# %%
sns.boxplot(x='Category',y='Profit',data=Data)
# Out:
# <AxesSubplot:xlabel='Category', ylabel='Profit'>

# %% [markdown]
# ### _Conclusion:_
# - **We can clearly see that variation in Technology sector is more as compared to other two sector.**

# %% [markdown]
# ### 12. Lets find the sectors which are having maxium sales and maximum profits.

# %%
pivot=pd.pivot_table(Data,index='Category',values='Sales')
pivot.plot(kind='bar', color="orange")
# Out:
# <AxesSubplot:xlabel='Category'>

# %%
pivot=pd.pivot_table(Data,index='Category',values='Profit')
pivot.plot(kind='bar', color="orange")
# Out:
# <AxesSubplot:xlabel='Category'>

# %% [markdown]
# ### _Conclusion:_
# - **Technology and Furniture sectore are somehow close in sales.**
# - **But, Profit of Technology sector is far more than other sectors.**

# %% [markdown]
# ## Overall Conclusion of Exploratory Data Analysis

# %% [markdown]
# - **California, New York, Texas, Washington, and Pennsylvania are the leading states in sales.**
# - **California tops the table by having 400000 sales.**
# - **California, New York, Washington, Michigan, and Virginia, sharing most of the profits.**
# - **California and New York states having maximum profits.**
# - **In above we see that there is some relation between sales and profit and also there is some relation between Discount and Profit.<br>**
# - **Plotting heat will give more clearity over this.**
# - **sales and profits are positively correlated.**
# - **Discount and Profits are Negatively correlated.**
# - **Above analysis clearly states that Copiers had maximum profit and machines had maximum loss.**
# - **Copiers and Machines has first snd second highest sales respectivey.**
# - **Above plot states that overall each segment is profitable in every region.**
# - **Furniture category is the only loss making sector that to only in Central Region.**
# - **Losses are inccured in Furniture Cateory irrespective to ship mode in Central Region**
# - **There is unusually high positive correlation between Postal Code and Discount.**
# - **Also, Their is negative correlation between Discount and Sales eventhough dicounts are entered as positive values... i.e. they are not helping in improving sales of "Furniture" category of the company.**
# - **Texas and Illiois are only two states contributing to all the losses in Furniture category in the Central Region
# Losses in Tables Sub Category is significanlty high.**
# - **Texas and Illinois are only states providing discounts in the whole central region this justifies high positive correlation between postal codes and discounts.**
# - **We can clearly see that variation in Technology sector is more as compared to other two sector.**
# - **Technology and Furniture sectore are somehow close in sales.**
# - **But, Profit of Technology sector is far more than other sectors.**
